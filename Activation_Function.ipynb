# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagadeesh1406/fmllab/blob/main/Activation_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
  return 1 / (1+np.exp(-x))

# %%
x = np.linspace(-10,10)
plt.plot(x, sigmoid(x))
plt.axis('tight')
plt.title('Activation Function :Sigmoid')
plt.show()

# %%
def tanh(x):
  return np.tanh(x)
x=np.linspace(-19,7)
plt.plot(x,tanh(x))
plt.title('Activation function tanh')
# Out:
# Text(0.5, 1.0, 'Activation function tanh')

# %%
def RELU(x):
  x1=[]
  for i in x:
    if i<0:
      x1.append(0)
    else:
      x1.append(i)
  return x1

x = np.linspace(-10, 10)
plt.plot(x,RELU(x))
plt.axis('tight')
plt.title('Activation Function : RELU')
plt.show()

# %%
def sigmoid(x, w, b):
  return 1/(1 + np.exp(-(w*x+b)))

# %%
sigmoid(1, 0.5, 0)
# Out:
# 0.6224593312018546

# %%
w = 0.9
b = 0.1
x = np.linspace(-10, 10, 100)
y = sigmoid(x, w, b)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
type(y)
# Out:
# numpy.ndarray

# %%
plt.plot(x,y)
plt.show()

# %%
w = -0.9
b = 0.1
x = np.linspace(-10, 10, 100)
y = sigmoid(x, w, b)
plt.plot(x,y)
plt.show()

# %%
w = -2
b = 0.1
x = np.linspace(-10, 10, 100)
y = sigmoid(x, w, b)
plt.plot(x,y)
plt.show()

# %%
def sigmoid_2d(x1, x2, w1, w2, b):
 return 1/(1+np.exp(-(w1*x1 + w2*x2 + b)))

# %%
sigmoid_2d(1, 0, 0.5, 0, 0)
# Out:
# 0.6224593312018546
